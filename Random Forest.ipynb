# %% [markdown]
# # Predicting Chicago Taxi Pickup Density using Random Forest

# %% [markdown]
# ## Importing libraries

# %%
import os
os.chdir('/Users/Kevin/Documents/TAMIDS Taxi Data')

import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
import random
import math
import datetime
import time

# %% [markdown]
# ## Data

# %%
x_train = pd.read_csv('PickupData.csv')
x_test = pd.read_csv('PickupDataTest.csv')

# %% [markdown]
# A preview of our data.

# %%
x_train.head()
# Out:
#    Year_num  Month  Hour  Day  WDay   Latitude  Longitude  Pickups  Month_num  \
# 0  0.202740      3    17   15     5  41.879255 -87.642649        2   0.466667
# 1  0.106849      2    19    8     5  41.893216 -87.637844        1   0.233333
# 2  0.339726      5    20    4     6  41.916005 -87.675095        3   0.100000
# 3  0.695890      9    12   11     3  41.884987 -87.620993        4   0.333333
# 4  0.953425     12    21   14     6  41.906026 -87.675312        2   0.433333
#
#    Hour_num   Day_num  Year_sin  Year_cos  Month_sin  Month_cos  Hour_sin  \
# 0  0.750000  0.678571  0.956235  0.292600   0.207912  -0.978148 -1.000000
# 1  0.833333  0.690476  0.622047  0.782980   0.994522   0.104528 -0.866025
# 2  0.875000  0.839286  0.845249 -0.534373   0.587785   0.809017 -0.707107
# 3  0.541667  0.363095 -0.942761 -0.333469   0.866025  -0.500000 -0.258819
# 4  0.916667  0.845238 -0.288482  0.957485   0.406737  -0.913545 -0.500000
#
#        Hour_cos   Day_sin   Day_cos
# 0 -1.836970e-16 -0.900969 -0.433884
# 1  5.000000e-01 -0.930874 -0.365341
# 2  7.071068e-01 -0.846724  0.532032
# 3 -9.659258e-01  0.757972 -0.652287
# 4  8.660254e-01 -0.826239  0.563320

# %% [markdown]
# ### Defining Time Variables
# The time granularity with respect to the granularity of location will be defined as bins per day (hours per day).  We must adjust our timestamps accordingly. Note that our data was processed in R.
# * **Hour_num**: Using a 24-hour clock, the hours will be defined from 1-24 (1:00am is 1, 12:00am is 24). Using the **strptime()** function, the hours are defined from 0-23, so we just add 1 to correct this. The formula for this calculation is:
# \begin{equation}
# HourNum = (Hour+1)/24
# \end{equation}
#
# * **Day_num**: The day of the week will be defined from 0-6 (Monday is 0, Sunday is 6), and we will incorporate hour of day in this calculation also. The formula for this calculation is:
# \begin{equation}
# DayNum = (((WDay-1) \mod 7)+(Hour+1)/24)/7
# \end{equation}
# **WDay** is the day of the week.
# Example: Friday, 2:00pm (Day = 5, Hour = 14)
# \begin{equation}
#     DayNum = ((5 \mod 7)+(14+1)/24)/7
# \end{equation}
# We do **WDay**-1 to count all of the days of the week previous to Friday. Since our range of integers for week is defined on the interval [0,6] we will be doing calculations for day of the week on mod 7. Then finally we divide by 7, the number of days in a week.
#
# * **Month_num**: The day of the month.
# \begin{equation}
# MonthNum = (Day-1)/30
# \end{equation}
#
# * **Year_num**: The day of the year will defined on a scale of 1-365. The **strptime()** function defines the day of the year from 0-364, so like hour, we add an correction factor of 1. The formula for this calculation is:
# \begin{equation}
# YearNum = (YearDay+1)/365
# \end{equation}
#
# Note: For 2016, we used 366 to count since it is a leap year.
#
# * **Sine** and **Cosine**: We capture cyclicality by applying sine and cosine functions to our calculated time, month, day, and year numbers.

# %% [markdown]
# ### Create response variables

# %%
y_pickup_train = np.log10(x_train['Pickups']+1)
y_pickup_test = np.log10(x_test['Pickups']+1)

# %%
# Remove pickup and wday column from training and testing data
pickup_train = x_train.drop(['Pickups', 'WDay'], axis=1)
pickup_test = x_test.drop(['Pickups', 'WDay'], axis=1)

# %% [markdown]
# ## Model Building
# ### Optimizing the random forest hyper-parameters
# Before we run our model, we want to find the best parameters to run the model with, in particular, we want to optimize the number of trees to use, the depth of the trees, and the number of variables considered at each split. We will use a 5-fold cross validation function to find the best parameters.

# %%
def optimize_params(clf, params, X, y):
    cv = GridSearchCV(clf, param_grid=params, n_jobs=1, cv=5, verbose=3)
    cv.fit(X, y)
    print('Best parameters:', cv.best_params_)
    print('Best score:', cv.best_score_)
    print('Best estimators:', cv.best_estimator_)

# %% [markdown]
# #### Defining the range of parameters
# Note that **n_estimators** is the number of trees, **max_features** is the number of variables considered at each split, and **max_depth** is the depth of the trees.

# %%
rf_estimator = RandomForestRegressor(n_estimators=20, n_jobs=-1)

params = {'n_estimators': [1, 2, 5, 10, 30, 50, 100],
          'max_features': ['auto', 'log2'],
          'max_depth': [10, 20, 50, 100]
         }

start_time = time.time()
best_params = optimize_params(rf_estimator, params, pickup_train, y_pickup_train)
time.time() - start_time
# Out:
# Fitting 5 folds for each of 56 candidates, totalling 280 fits
# [CV] max_depth=10, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=1, score=0.559440, total=   2.2s
# [CV] max_depth=10, max_features=auto, n_estimators=1 .................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.3s remaining:    0.0s
# [CV]  max_depth=10, max_features=auto, n_estimators=1, score=0.612251, total=   2.2s
# [CV] max_depth=10, max_features=auto, n_estimators=1 .................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    4.6s remaining:    0.0s
# [CV]  max_depth=10, max_features=auto, n_estimators=1, score=0.615317, total=   2.1s
# [CV] max_depth=10, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=1, score=0.611700, total=   2.1s
# [CV] max_depth=10, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=1, score=0.558787, total=   2.1s
# [CV] max_depth=10, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=2, score=0.565525, total=   2.6s
# [CV] max_depth=10, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=2, score=0.616767, total=   2.6s
# [CV] max_depth=10, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=2, score=0.620318, total=   2.6s
# [CV] max_depth=10, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=2, score=0.616743, total=   2.6s
# [CV] max_depth=10, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=2, score=0.565599, total=   2.5s
# [CV] max_depth=10, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=5, score=0.568239, total=   3.9s
# [CV] max_depth=10, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=5, score=0.619466, total=   3.9s
# [CV] max_depth=10, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=5, score=0.622651, total=   3.9s
# [CV] max_depth=10, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=5, score=0.618336, total=   4.0s
# [CV] max_depth=10, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=10, max_features=auto, n_estimators=5, score=0.569112, total=   3.9s
# [CV] max_depth=10, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=10, score=0.568881, total=   8.2s
# [CV] max_depth=10, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=10, score=0.620670, total=   8.2s
# [CV] max_depth=10, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=10, score=0.623815, total=   8.2s
# [CV] max_depth=10, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=10, score=0.619361, total=   8.2s
# [CV] max_depth=10, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=10, score=0.570462, total=   8.2s
# [CV] max_depth=10, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=30, score=0.569266, total=  21.4s
# [CV] max_depth=10, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=30, score=0.621259, total=  21.6s
# [CV] max_depth=10, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=30, score=0.624219, total=  21.5s
# [CV] max_depth=10, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=30, score=0.620186, total=  21.5s
# [CV] max_depth=10, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=30, score=0.570721, total=  21.7s
# [CV] max_depth=10, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=50, score=0.569768, total=  36.5s
# [CV] max_depth=10, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=50, score=0.621234, total=  36.9s
# [CV] max_depth=10, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=50, score=0.624242, total=  36.4s
# [CV] max_depth=10, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=50, score=0.620450, total=  36.6s
# [CV] max_depth=10, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=10, max_features=auto, n_estimators=50, score=0.570956, total=  37.0s
# [CV] max_depth=10, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=auto, n_estimators=100, score=0.569641, total= 1.2min
# [CV] max_depth=10, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=auto, n_estimators=100, score=0.621275, total= 1.2min
# [CV] max_depth=10, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=auto, n_estimators=100, score=0.624468, total= 1.2min
# [CV] max_depth=10, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=auto, n_estimators=100, score=0.620398, total=93.1min
# [CV] max_depth=10, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=auto, n_estimators=100, score=0.571184, total= 2.3min
# [CV] max_depth=10, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=1, score=0.466810, total=   2.3s
# [CV] max_depth=10, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=1, score=0.540672, total=   1.8s
# [CV] max_depth=10, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=1, score=0.544281, total=   1.7s
# [CV] max_depth=10, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=1, score=0.447568, total=   1.7s
# [CV] max_depth=10, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=1, score=0.539146, total=   1.7s
# [CV] max_depth=10, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=2, score=0.512723, total=   1.6s
# [CV] max_depth=10, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=2, score=0.551522, total=   1.7s
# [CV] max_depth=10, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=2, score=0.516677, total=   1.6s
# [CV] max_depth=10, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=2, score=0.590157, total=   1.7s
# [CV] max_depth=10, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=2, score=0.530462, total=   1.6s
# [CV] max_depth=10, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=5, score=0.550823, total=   2.2s
# [CV] max_depth=10, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=5, score=0.557880, total=   2.3s
# [CV] max_depth=10, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=5, score=0.583998, total=   2.4s
# [CV] max_depth=10, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=5, score=0.581069, total=   2.3s
# [CV] max_depth=10, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=10, max_features=log2, n_estimators=5, score=0.555684, total=   2.2s
# [CV] max_depth=10, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=10, score=0.555615, total=   4.5s
# [CV] max_depth=10, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=10, score=0.569776, total=   4.5s
# [CV] max_depth=10, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=10, score=0.575308, total=   4.5s
# [CV] max_depth=10, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=10, score=0.584738, total=   4.6s
# [CV] max_depth=10, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=10, score=0.546476, total=   5.2s
# [CV] max_depth=10, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=30, score=0.558156, total=  11.2s
# [CV] max_depth=10, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=30, score=0.581067, total=  10.7s
# [CV] max_depth=10, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=30, score=0.572669, total=  11.6s
# [CV] max_depth=10, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=30, score=0.590424, total=  11.4s
# [CV] max_depth=10, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=30, score=0.568443, total=  11.5s
# [CV] max_depth=10, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=50, score=0.556932, total=  18.0s
# [CV] max_depth=10, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=50, score=0.588406, total=  19.2s
# [CV] max_depth=10, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=50, score=0.585809, total=  18.0s
# [CV] max_depth=10, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=50, score=0.594116, total=  18.3s
# [CV] max_depth=10, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=10, max_features=log2, n_estimators=50, score=0.570216, total=  19.1s
# [CV] max_depth=10, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=log2, n_estimators=100, score=0.558604, total=  35.2s
# [CV] max_depth=10, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=log2, n_estimators=100, score=0.590537, total=  35.5s
# [CV] max_depth=10, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=log2, n_estimators=100, score=0.585481, total=  35.4s
# [CV] max_depth=10, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=log2, n_estimators=100, score=0.589673, total=  36.4s
# [CV] max_depth=10, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=10, max_features=log2, n_estimators=100, score=0.566365, total=  35.0s
# [CV] max_depth=20, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=1, score=0.432941, total=   9.7s
# [CV] max_depth=20, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=1, score=0.629447, total=   8.7s
# [CV] max_depth=20, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=1, score=0.637581, total=   8.1s
# [CV] max_depth=20, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=1, score=0.517900, total=   6.5s
# [CV] max_depth=20, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=1, score=0.365630, total=   5.5s
# [CV] max_depth=20, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=2, score=0.528992, total=   6.0s
# [CV] max_depth=20, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=2, score=0.694782, total=   6.8s
# [CV] max_depth=20, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=2, score=0.701775, total=   7.2s
# [CV] max_depth=20, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=2, score=0.602700, total=   7.2s
# [CV] max_depth=20, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=2, score=0.459522, total=   7.9s
# [CV] max_depth=20, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=5, score=0.587392, total=  10.6s
# [CV] max_depth=20, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=5, score=0.733196, total=  12.5s
# [CV] max_depth=20, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=5, score=0.744406, total=  14.2s
# [CV] max_depth=20, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=5, score=0.650541, total=  12.5s
# [CV] max_depth=20, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=20, max_features=auto, n_estimators=5, score=0.525056, total=  13.7s
# [CV] max_depth=20, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=10, score=0.605057, total=  26.9s
# [CV] max_depth=20, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=10, score=0.748090, total=  26.9s
# [CV] max_depth=20, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=10, score=0.756893, total=  27.5s
# [CV] max_depth=20, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=10, score=0.667678, total=  27.7s
# [CV] max_depth=20, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=10, score=0.545572, total=  27.5s
# [CV] max_depth=20, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=30, score=0.615596, total= 1.1min
# [CV] max_depth=20, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=30, score=0.756136, total= 1.1min
# [CV] max_depth=20, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=30, score=0.765902, total= 1.1min
# [CV] max_depth=20, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=30, score=0.678182, total= 1.1min
# [CV] max_depth=20, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=30, score=0.559657, total= 1.1min
# [CV] max_depth=20, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=50, score=0.618699, total= 1.9min
# [CV] max_depth=20, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=50, score=0.757916, total= 1.9min
# [CV] max_depth=20, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=50, score=0.766704, total=86.7min
# [CV] max_depth=20, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=50, score=0.680446, total= 2.0min
# [CV] max_depth=20, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=20, max_features=auto, n_estimators=50, score=0.560153, total= 1.9min
# [CV] max_depth=20, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=auto, n_estimators=100, score=0.620555, total= 3.6min
# [CV] max_depth=20, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=auto, n_estimators=100, score=0.759156, total= 3.7min
# [CV] max_depth=20, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=auto, n_estimators=100, score=0.769157, total= 3.7min
# [CV] max_depth=20, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=auto, n_estimators=100, score=0.681960, total= 3.7min
# [CV] max_depth=20, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=auto, n_estimators=100, score=0.563258, total= 3.6min
# [CV] max_depth=20, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=1, score=0.426473, total=   3.0s
# [CV] max_depth=20, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=1, score=0.587247, total=   2.9s
# [CV] max_depth=20, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=1, score=0.582284, total=   2.8s
# [CV] max_depth=20, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=1, score=0.497873, total=   2.7s
# [CV] max_depth=20, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=1, score=0.353552, total=   2.4s
# [CV] max_depth=20, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=2, score=0.535385, total=   2.6s
# [CV] max_depth=20, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=2, score=0.689179, total=   2.6s
# [CV] max_depth=20, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=2, score=0.694599, total=   2.6s
# [CV] max_depth=20, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=2, score=0.596650, total=   2.6s
# [CV] max_depth=20, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=2, score=0.471076, total=   2.7s
# [CV] max_depth=20, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=5, score=0.590300, total=   3.6s
# [CV] max_depth=20, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=5, score=0.735235, total=   3.5s
# [CV] max_depth=20, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=5, score=0.748640, total=   3.6s
# [CV] max_depth=20, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=5, score=0.651934, total=   3.7s
# [CV] max_depth=20, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=20, max_features=log2, n_estimators=5, score=0.526550, total=   3.6s
# [CV] max_depth=20, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=10, score=0.614389, total=   7.7s
# [CV] max_depth=20, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=10, score=0.750751, total=   7.9s
# [CV] max_depth=20, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=10, score=0.756200, total=   7.6s
# [CV] max_depth=20, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=10, score=0.669851, total=   7.4s
# [CV] max_depth=20, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=10, score=0.552947, total=   8.2s
# [CV] max_depth=20, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=30, score=0.626634, total=  17.4s
# [CV] max_depth=20, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=30, score=0.757292, total=  19.1s
# [CV] max_depth=20, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=30, score=0.768969, total=  18.6s
# [CV] max_depth=20, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=30, score=0.681579, total=  18.2s
# [CV] max_depth=20, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=30, score=0.564425, total=  18.6s
# [CV] max_depth=20, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=50, score=0.629298, total=  31.2s
# [CV] max_depth=20, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=50, score=0.762244, total=82.5min
# [CV] max_depth=20, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=50, score=0.771996, total=  26.0s
# [CV] max_depth=20, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=50, score=0.683372, total=  32.1s
# [CV] max_depth=20, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=20, max_features=log2, n_estimators=50, score=0.567710, total=  32.1s
# [CV] max_depth=20, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=log2, n_estimators=100, score=0.631978, total= 1.0min
# [CV] max_depth=20, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=log2, n_estimators=100, score=0.763821, total=  59.0s
# [CV] max_depth=20, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=log2, n_estimators=100, score=0.771671, total=  58.7s
# [CV] max_depth=20, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=log2, n_estimators=100, score=0.685984, total=  58.5s
# [CV] max_depth=20, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=20, max_features=log2, n_estimators=100, score=0.569902, total=  58.8s
# [CV] max_depth=50, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=1, score=0.350604, total=  11.4s
# [CV] max_depth=50, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=1, score=0.640720, total=   9.2s
# [CV] max_depth=50, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=1, score=0.665291, total=   8.4s
# [CV] max_depth=50, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=1, score=0.460448, total=   7.1s
# [CV] max_depth=50, max_features=auto, n_estimators=1 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=1, score=0.198864, total=   6.2s
# [CV] max_depth=50, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=2, score=0.495697, total=   6.1s
# [CV] max_depth=50, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=2, score=0.743491, total=   7.1s
# [CV] max_depth=50, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=2, score=0.760303, total=   8.1s
# [CV] max_depth=50, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=2, score=0.593170, total=   8.7s
# [CV] max_depth=50, max_features=auto, n_estimators=2 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=2, score=0.367466, total=   8.6s
# [CV] max_depth=50, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=5, score=0.586766, total=  12.3s
# [CV] max_depth=50, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=5, score=0.801972, total=  13.9s
# [CV] max_depth=50, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=5, score=0.815837, total=  15.3s
# [CV] max_depth=50, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=5, score=0.673046, total=  15.0s
# [CV] max_depth=50, max_features=auto, n_estimators=5 .................
# [CV]  max_depth=50, max_features=auto, n_estimators=5, score=0.460916, total=  15.2s
# [CV] max_depth=50, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=10, score=0.616045, total=  30.3s
# [CV] max_depth=50, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=10, score=0.819622, total=  30.6s
# [CV] max_depth=50, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=10, score=0.834344, total=  30.7s
# [CV] max_depth=50, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=10, score=0.699718, total=  30.6s
# [CV] max_depth=50, max_features=auto, n_estimators=10 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=10, score=0.493935, total=  30.3s
# [CV] max_depth=50, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=30, score=0.637337, total= 1.2min
# [CV] max_depth=50, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=30, score=0.832385, total= 1.3min
# [CV] max_depth=50, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=30, score=0.846693, total= 1.2min
# [CV] max_depth=50, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=30, score=0.716971, total= 1.2min
# [CV] max_depth=50, max_features=auto, n_estimators=30 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=30, score=0.516474, total= 1.2min
# [CV] max_depth=50, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=50, score=0.639542, total= 2.1min
# [CV] max_depth=50, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=50, score=0.835127, total= 2.1min
# [CV] max_depth=50, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=50, score=0.849586, total= 2.1min
# [CV] max_depth=50, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=50, score=0.720089, total= 2.1min
# [CV] max_depth=50, max_features=auto, n_estimators=50 ................
# [CV]  max_depth=50, max_features=auto, n_estimators=50, score=0.520507, total= 2.1min
# [CV] max_depth=50, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=auto, n_estimators=100, score=0.643722, total= 4.1min
# [CV] max_depth=50, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=auto, n_estimators=100, score=0.836893, total= 4.0min
# [CV] max_depth=50, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=auto, n_estimators=100, score=0.851128, total= 4.1min
# [CV] max_depth=50, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=auto, n_estimators=100, score=0.722009, total= 4.1min
# [CV] max_depth=50, max_features=auto, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=auto, n_estimators=100, score=0.525270, total= 4.1min
# [CV] max_depth=50, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=1, score=0.349059, total=   3.4s
# [CV] max_depth=50, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=1, score=0.638589, total=   3.3s
# [CV] max_depth=50, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=1, score=0.665572, total=   3.2s
# [CV] max_depth=50, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=1, score=0.438307, total=   2.7s
# [CV] max_depth=50, max_features=log2, n_estimators=1 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=1, score=0.192254, total=   2.6s
# [CV] max_depth=50, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=2, score=0.503048, total=   2.6s
# [CV] max_depth=50, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=2, score=0.744133, total=   2.9s
# [CV] max_depth=50, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=2, score=0.763344, total=   3.1s
# [CV] max_depth=50, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=2, score=0.592132, total=   3.1s
# [CV] max_depth=50, max_features=log2, n_estimators=2 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=2, score=0.365455, total=   2.8s
# [CV] max_depth=50, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=5, score=0.595623, total=   3.7s
# [CV] max_depth=50, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=5, score=0.806501, total=   3.6s
# [CV] max_depth=50, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=5, score=0.822228, total=   3.8s
# [CV] max_depth=50, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=5, score=0.673854, total=   4.2s
# [CV] max_depth=50, max_features=log2, n_estimators=5 .................
# [CV]  max_depth=50, max_features=log2, n_estimators=5, score=0.453929, total=   4.7s
# [CV] max_depth=50, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=10, score=0.626281, total=   9.2s
# [CV] max_depth=50, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=10, score=0.826891, total=   8.7s
# [CV] max_depth=50, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=10, score=0.840923, total=   9.3s
# [CV] max_depth=50, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=10, score=0.701045, total=   8.6s
# [CV] max_depth=50, max_features=log2, n_estimators=10 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=10, score=0.483902, total=   8.3s
# [CV] max_depth=50, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=30, score=0.647703, total=  21.3s
# [CV] max_depth=50, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=30, score=0.840133, total=  21.7s
# [CV] max_depth=50, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=30, score=0.853625, total=  21.1s
# [CV] max_depth=50, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=30, score=0.716367, total=  20.1s
# [CV] max_depth=50, max_features=log2, n_estimators=30 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=30, score=0.507641, total=  20.3s
# [CV] max_depth=50, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=50, score=0.650888, total=  35.1s
# [CV] max_depth=50, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=50, score=0.842409, total=  35.2s
# [CV] max_depth=50, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=50, score=0.856057, total=  35.1s
# [CV] max_depth=50, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=50, score=0.722225, total=  34.8s
# [CV] max_depth=50, max_features=log2, n_estimators=50 ................
# [CV]  max_depth=50, max_features=log2, n_estimators=50, score=0.512562, total=  34.2s
# [CV] max_depth=50, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=log2, n_estimators=100, score=0.653803, total= 1.1min
# [CV] max_depth=50, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=log2, n_estimators=100, score=0.844444, total= 1.1min
# [CV] max_depth=50, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=log2, n_estimators=100, score=0.858086, total= 1.1min
# [CV] max_depth=50, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=log2, n_estimators=100, score=0.725236, total= 1.1min
# [CV] max_depth=50, max_features=log2, n_estimators=100 ...............
# [CV]  max_depth=50, max_features=log2, n_estimators=100, score=0.513808, total=41.5min
# [CV] max_depth=100, max_features=auto, n_estimators=1 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=1, score=0.342620, total=   3.5s
# [CV] max_depth=100, max_features=auto, n_estimators=1 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=1, score=0.643663, total=   3.8s
# [CV] max_depth=100, max_features=auto, n_estimators=1 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=1, score=0.662976, total=   3.3s
# [CV] max_depth=100, max_features=auto, n_estimators=1 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=1, score=0.468196, total=   3.7s
# [CV] max_depth=100, max_features=auto, n_estimators=1 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=1, score=0.196569, total=   4.0s
# [CV] max_depth=100, max_features=auto, n_estimators=2 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=2, score=0.500745, total=   3.7s
# [CV] max_depth=100, max_features=auto, n_estimators=2 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=2, score=0.744274, total=   3.7s
# [CV] max_depth=100, max_features=auto, n_estimators=2 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=2, score=0.758840, total=   4.0s
# [CV] max_depth=100, max_features=auto, n_estimators=2 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=2, score=0.593082, total=   4.0s
# [CV] max_depth=100, max_features=auto, n_estimators=2 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=2, score=0.359406, total=   3.7s
# [CV] max_depth=100, max_features=auto, n_estimators=5 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=5, score=0.587253, total=   4.7s
# [CV] max_depth=100, max_features=auto, n_estimators=5 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=5, score=0.801032, total=   5.5s
# [CV] max_depth=100, max_features=auto, n_estimators=5 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=5, score=0.815489, total=   5.7s
# [CV] max_depth=100, max_features=auto, n_estimators=5 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=5, score=0.673330, total=   5.4s
# [CV] max_depth=100, max_features=auto, n_estimators=5 ................
# [CV]  max_depth=100, max_features=auto, n_estimators=5, score=0.462788, total=   5.4s
# [CV] max_depth=100, max_features=auto, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=10, score=0.615275, total=  11.7s
# [CV] max_depth=100, max_features=auto, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=10, score=0.819495, total=  11.5s
# [CV] max_depth=100, max_features=auto, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=10, score=0.834740, total=  11.6s
# [CV] max_depth=100, max_features=auto, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=10, score=0.698897, total=  11.6s
# [CV] max_depth=100, max_features=auto, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=10, score=0.495241, total=  11.6s
# [CV] max_depth=100, max_features=auto, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=30, score=0.637472, total=  29.8s
# [CV] max_depth=100, max_features=auto, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=30, score=0.832627, total=  27.1s
# [CV] max_depth=100, max_features=auto, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=30, score=0.846784, total=  30.3s
# [CV] max_depth=100, max_features=auto, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=30, score=0.716362, total=  30.1s
# [CV] max_depth=100, max_features=auto, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=30, score=0.518152, total=  30.0s
# [CV] max_depth=100, max_features=auto, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=50, score=0.640041, total=  51.0s
# [CV] max_depth=100, max_features=auto, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=50, score=0.834798, total=  50.9s
# [CV] max_depth=100, max_features=auto, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=50, score=0.849565, total=  51.5s
# [CV] max_depth=100, max_features=auto, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=50, score=0.719206, total=  49.1s
# [CV] max_depth=100, max_features=auto, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=auto, n_estimators=50, score=0.522479, total=  51.0s
# [CV] max_depth=100, max_features=auto, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=auto, n_estimators=100, score=0.643386, total= 1.7min
# [CV] max_depth=100, max_features=auto, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=auto, n_estimators=100, score=0.836806, total= 1.7min
# [CV] max_depth=100, max_features=auto, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=auto, n_estimators=100, score=0.851108, total=14.8min
# [CV] max_depth=100, max_features=auto, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=auto, n_estimators=100, score=0.722515, total= 1.8min
# [CV] max_depth=100, max_features=auto, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=auto, n_estimators=100, score=0.525046, total= 1.8min
# [CV] max_depth=100, max_features=log2, n_estimators=1 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=1, score=0.357085, total=   1.0s
# [CV] max_depth=100, max_features=log2, n_estimators=1 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=1, score=0.630536, total=   1.1s
# [CV] max_depth=100, max_features=log2, n_estimators=1 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=1, score=0.656754, total=   1.2s
# [CV] max_depth=100, max_features=log2, n_estimators=1 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=1, score=0.463304, total=   1.1s
# [CV] max_depth=100, max_features=log2, n_estimators=1 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=1, score=0.178072, total=   1.0s
# [CV] max_depth=100, max_features=log2, n_estimators=2 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=2, score=0.501769, total=   1.2s
# [CV] max_depth=100, max_features=log2, n_estimators=2 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=2, score=0.742777, total=   1.3s
# [CV] max_depth=100, max_features=log2, n_estimators=2 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=2, score=0.763245, total=   1.3s
# [CV] max_depth=100, max_features=log2, n_estimators=2 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=2, score=0.589270, total=   1.2s
# [CV] max_depth=100, max_features=log2, n_estimators=2 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=2, score=0.353179, total=   1.3s
# [CV] max_depth=100, max_features=log2, n_estimators=5 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=5, score=0.593192, total=   2.0s
# [CV] max_depth=100, max_features=log2, n_estimators=5 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=5, score=0.806747, total=   1.9s
# [CV] max_depth=100, max_features=log2, n_estimators=5 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=5, score=0.820585, total=   2.0s
# [CV] max_depth=100, max_features=log2, n_estimators=5 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=5, score=0.670983, total=   1.9s
# [CV] max_depth=100, max_features=log2, n_estimators=5 ................
# [CV]  max_depth=100, max_features=log2, n_estimators=5, score=0.448761, total=   2.0s
# [CV] max_depth=100, max_features=log2, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=10, score=0.625212, total=   3.8s
# [CV] max_depth=100, max_features=log2, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=10, score=0.825653, total=   4.0s
# [CV] max_depth=100, max_features=log2, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=10, score=0.839518, total=   4.0s
# [CV] max_depth=100, max_features=log2, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=10, score=0.698285, total=   4.4s
# [CV] max_depth=100, max_features=log2, n_estimators=10 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=10, score=0.488069, total=   4.5s
# [CV] max_depth=100, max_features=log2, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=30, score=0.646503, total=  11.9s
# [CV] max_depth=100, max_features=log2, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=30, score=0.839244, total=   9.6s
# [CV] max_depth=100, max_features=log2, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=30, score=0.853031, total=  10.0s
# [CV] max_depth=100, max_features=log2, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=30, score=0.719004, total=  12.4s
# [CV] max_depth=100, max_features=log2, n_estimators=30 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=30, score=0.507412, total=  10.4s
# [CV] max_depth=100, max_features=log2, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=50, score=0.651389, total=  14.3s
# [CV] max_depth=100, max_features=log2, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=50, score=0.842260, total=  16.1s
# [CV] max_depth=100, max_features=log2, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=50, score=0.856257, total=  16.0s
# [CV] max_depth=100, max_features=log2, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=50, score=0.721911, total=  15.8s
# [CV] max_depth=100, max_features=log2, n_estimators=50 ...............
# [CV]  max_depth=100, max_features=log2, n_estimators=50, score=0.511711, total=  15.8s
# [CV] max_depth=100, max_features=log2, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=log2, n_estimators=100, score=0.653762, total=  31.4s
# [CV] max_depth=100, max_features=log2, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=log2, n_estimators=100, score=0.844691, total=  31.7s
# [CV] max_depth=100, max_features=log2, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=log2, n_estimators=100, score=0.857889, total=  33.4s
# [CV] max_depth=100, max_features=log2, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=log2, n_estimators=100, score=0.724079, total=  32.1s
# [CV] max_depth=100, max_features=log2, n_estimators=100 ..............
# [CV]  max_depth=100, max_features=log2, n_estimators=100, score=0.514242, total=  31.3s
# [Parallel(n_jobs=1)]: Done 280 out of 280 | elapsed: 558.9min finished
# Best parameters: {'max_depth': 50, 'max_features': 'log2', 'n_estimators': 100}
# Best score: 0.719075403196
# Best estimators: RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,
#            max_features='log2', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=-1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)
# 33574.71210980415

# %% [markdown]
# After performing cross validation, here are the results we found:
# * **max_depth** = 50
# * **max_features** = log2
# * **n_estimators** = 100

# %% [markdown]
# ### Fitting the model
# We will use the parameters we found in the previous to fit our random forest model.

# %%
reg = RandomForestRegressor(n_estimators=100, max_depth=50, max_features='log2', n_jobs=1)

# %%
reg.fit(pickup_train, y_pickup_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,
#            max_features='log2', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %% [markdown]
# ### Make predictions and evaluating results

# %%
predicted_pickups = reg.predict(pickup_test)
accuracy_score(np.round(np.power(10, y_pickup_test)-1, decimals=0),
               np.round(np.power(10, predicted_pickups)-1, decimals=0))
# Out:
# 0.43662059133453168

# %% [markdown]
# Performing prediction on the 2017 test data, we get only a 43.66% accuracy rate, not so good. However, for our particular study, a low prediction accuracy does not necessary mean that our model is not good. This accuracy score only accounts for the number of pickups that our model has predicted exactly and does not factor in the proximity of our prediction, and considering the scale of the data we are working with, the proximity to the exact solution is pretty important to asses. For example, if a specific location had 1,000 true pickups, but our model predicted that same location would have 998 pickups. That prediction is not exactly correct but since we are working with a dataset containing several million pickups, a prediction that is off by only a factor of 2 is fairly accurate. So to take a further inspection on how good our model is, we must take into account how far are predictions are off from the true values and we can do that by calculating the root mean square error.

# %% [markdown]
# #### Calculate RMSE

# %%
rmse = np.sqrt(mean_squared_error(predicted_pickups, y_pickup_test))
rmse_back = np.power(10, rmse)
print("RMSE (log-space) = %0.3f" %rmse)
print("RMSE = %0.3f" %rmse_back)
# Out:
# RMSE (log-space) = 0.141
# RMSE = 1.382

# %% [markdown]
# Our calculated RMSE for our model was 0.141, but that is in log space so we must transform back. Doing so, we obtain a value of 1.382. That means our That means that the other 56% of our predictions are only a factor of 1.382 or less away from the true value. Now remember we are working with a dataset containing several million pickups, so our model being only a factor of 1.382 pickups away from the true pickup values means that model is predicting pickup values very close to the actual number of pickups. Knowing this, now our 43% prediction accuracy is actually quite considerably good.

# %% [markdown]
# #### Most important features

# %%
import operator
varImp = dict(zip(list(pickup_train.columns.values), reg.feature_importances_))
varImp_sorted = sorted(varImp.items(), key=operator.itemgetter(1), reverse=True)
varImp_sorted
# Out:
# [('Latitude', 0.27621509508875908),
#  ('Longitude', 0.23507218037847466),
#  ('Year_num', 0.050127152421569302),
#  ('Year_cos', 0.050009352118430349),
#  ('Year_sin', 0.049514385038255677),
#  ('Day_num', 0.049068821142499879),
#  ('Day_cos', 0.0310088031001606),
#  ('Month_num', 0.029413920719945082),
#  ('Day', 0.029375558051922376),
#  ('Month_cos', 0.028045684698258282),
#  ('Hour_num', 0.02783126044194419),
#  ('Day_sin', 0.027064419463383539),
#  ('Month_sin', 0.026630089073298717),
#  ('Hour', 0.025994081524676652),
#  ('Hour_sin', 0.025958827259884246),
#  ('Month', 0.019470573634985684),
#  ('Hour_cos', 0.019199795843551602)]

# %% [markdown]
# #### Write predicted values to csv file
# We will take our predicted pickups and output these values to a csv to create visualizations. We will be using Tableau to visualize our predicted values.

# %%
predicted_df = pd.DataFrame({'Latitude': pickup_test['Latitude'],
                             'Longitude': pickup_test['Longitude'],
                             'Year': np.repeat(2017, pickup_test.shape[0]),
                             'Day': pickup_test['Day'],
                             'Hour': pickup_test['Hour'],
                             'Month': pickup_test['Month'],
                             'WDay': x_test['WDay'],
                             'YDay': np.round(pickup_test['Year_num']*365),
                             'Pickups': np.round(np.power(10, predicted_pickups)-1, decimals=0)})
predicted_df.to_csv('PredictedPickups.csv', index=False)
